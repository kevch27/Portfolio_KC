# %% [markdown]
# # Kevin Chen's Portfolio Project - Step 3 Data Process

# %%
# Part of my Portfolio Project-Step 3 Data Process.
# Showcasing data cleaning and transformation using Python.
# Dataset source: https://www.gallup.com/analytics/318923/world-poll-public-datasets.aspx

# %% [markdown]
# ### Import libraries & modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# Import dataset
portfolio_df = pd.read_csv(r'D:\Work\Portfolio\Dataset\Rev08_Portfolio_Project.csv')

# %%
# Verify data loaded correctly
portfolio_df
# Out:
#       row_number   country                  demographic  \
# 0              1   Albania                          Age
# 1              2   Albania                          Age
# 2              3   Albania                          Age
# 3              4   Albania                          Age
# 4              5   Albania                          Age
# ...          ...       ...                          ...
# 1347        1348  Zimbabwe  Per Capita Income Quintiles
# 1348        1349  Zimbabwe                  Urban/Rural
# 1349        1350  Zimbabwe                  Urban/Rural
# 1350        1351  Zimbabwe                  Urban/Rural
# 1351        1352  Zimbabwe                  Urban/Rural
#
#                         segment  struggling_index  suffering_index  \
# 0                         15-24             0.464            0.033
# 1                         25-34             0.601            0.121
# 2                         35-44             0.640            0.204
# ...

# %% [markdown]
# ### Data Cleaning - check missing data

# %%
# Find missing data using FOR loop
for col in portfolio_df.columns:
    pct_missing = np.mean(portfolio_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# row_number - 0%
# country - 0%
# demographic - 0%
# segment - 0%
# struggling_index - 0%
# suffering_index - 0%
# thriving_index - 0%
# health_problems__yes - 0%
# health_problems__no - 0%
# health_problems__unsure - 0%
# health_problems__decline - 0%
# reliable_help__yes - 0%
# reliable_help__no - 0%
# reliable_help__unsure - 0%
# reliable_help__decline - 0%
# recent_calmness__yes - 0%
# recent_calmness__no - 0%
# recent_calmness__unsure - 0%
# recent_calmness__decline - 0%
# life_at_peace__yes - 0%
# life_at_peace__no - 0%
# life_at_peace__unsure - 0%
# life_at_peace__decline - 0%
# exciting_life_or_calm_life__exciting - 0%
# exciting_life_or_calm_life__calm - 0%
# exciting_life_or_calm_life__both - 0%
# exciting_life_or_calm_life__neither - 0%
# exciting_life_or_calm_life__unsure - 0%
# exciting_life_or_calm_life__decline - 0%
# life_in_balance__yes - 0%
# life_in_balance__no - 0%
# life_in_balance__unsure - 0%
# life_in_balance__decline - 0%
# ...

# %%
# Confirm the exact number of missing value
print(portfolio_df.isnull().sum())
# Out:
# row_number                                    0
# country                                       0
# demographic                                   0
# segment                                       0
# struggling_index                              0
# suffering_index                               0
# thriving_index                                0
# health_problems__yes                          0
# health_problems__no                           0
# health_problems__unsure                       0
# health_problems__decline                      0
# reliable_help__yes                            0
# reliable_help__no                             0
# reliable_help__unsure                         0
# reliable_help__decline                        0
# recent_calmness__yes                          0
# recent_calmness__no                           0
# recent_calmness__unsure                       0
# recent_calmness__decline                      0
# life_at_peace__yes                            0
# ...

# %%
print(portfolio_df.dtypes)
# Out:
# row_number                                      int64
# country                                        object
# demographic                                    object
# segment                                        object
# struggling_index                              float64
# suffering_index                               float64
# thriving_index                                float64
# health_problems__yes                          float64
# health_problems__no                           float64
# health_problems__unsure                       float64
# health_problems__decline                      float64
# reliable_help__yes                            float64
# reliable_help__no                             float64
# reliable_help__unsure                         float64
# reliable_help__decline                        float64
# recent_calmness__yes                          float64
# recent_calmness__no                           float64
# ...

# %%
# Create 'primary_key' column
# portfolio_df['primary_key'] = portfolio_df['country'] + '_' + portfolio_df['demographic'] + '_' + portfolio_df['segment']

# %%
# Print the updated DataFrame
# print(portfolio_df)

# %%
# Export to .csv file
# portfolio_df.to_csv('output.csv', index=False)

# %%
# Check priamry_key column for duplicate entries
duplicates = portfolio_df.duplicated(subset='primary_key')

# Print the duplicate rows, if any
if duplicates.any():
    duplicate_rows = df[duplicates]
    print("Duplicate rows based on 'primary_key' column:")
    print(duplicate_rows)
else:
    print("No duplicate values found in the 'primary_key' column.")
# Out:
# No duplicate values found in the 'primary_key' column.
