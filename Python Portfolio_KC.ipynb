# %% [markdown]
# # Kevin Chen's Python Demonstration

# %%
# Determine data correlation using Python
# Dataset source: https://www.kaggle.com/datasets/danielgrijalvas/movies

# %% [markdown]
# ### Import libraries & modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Read the data file

# %%
df = pd.read_csv(r'D:\Work\Data Analysis Portfolio\Python Portfolio\movies.csv')

# %%
# Taking first look at the data
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# ### Data Cleaning - remove missing data

# %%
# Find missing data using FOR loop
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Examining rows with missing data in the 'budget' column
missing_budget = df[df['budget'].isna()]
missing_budget.head(3)
# Out:
#             name rating   genre  year                           released  \
# 16          Fame      R   Drama  1980       May 16, 1980 (United States)
# 19    Stir Crazy      R  Comedy  1980  December 12, 1980 (United States)
# 24  Urban Cowboy     PG   Drama  1980       June 6, 1980 (United States)
#
#     score    votes        director              writer           star  \
# 16    6.6  21000.0     Alan Parker    Christopher Gore    Eddie Barth
# 19    6.8  26000.0  Sidney Poitier  Bruce Jay Friedman    Gene Wilder
# 24    6.4  14000.0   James Bridges        Aaron Latham  John Travolta
#
#           country  budget        gross                    company  runtime
# 16  United States     NaN   21202829.0  Metro-Goldwyn-Mayer (MGM)    134.0
# 19  United States     NaN  101300000.0          Columbia Pictures    111.0
# 24  United States     NaN   46918287.0         Paramount Pictures    132.0

# %%
# Drop rows with missing values
df = df.dropna()

# %%
# Confirm the number of missing values after dropping rows
print(df.isnull().sum())
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %% [markdown]
# ### Data Cleaning - change data type

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Snapshot before making the change
df.head(1)
# Out:
#           name rating  genre  year                       released  score  \
# 0  The Shining      R  Drama  1980  June 13, 1980 (United States)    8.4
#
#       votes         director        writer            star         country  \
# 0  927000.0  Stanley Kubrick  Stephen King  Jack Nicholson  United Kingdom
#
#        budget       gross       company  runtime
# 0  19000000.0  46998772.0  Warner Bros.    146.0

# %%
# change data type of columns
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
# Snapshot after making the change
df.head(1)
# Out:
#           name rating  genre  year                       released  score  \
# 0  The Shining      R  Drama  1980  June 13, 1980 (United States)    8.4
#
#     votes         director        writer            star         country  \
# 0  927000  Stanley Kubrick  Stephen King  Jack Nicholson  United Kingdom
#
#      budget     gross       company  runtime
# 0  19000000  46998772  Warner Bros.      146

# %% [markdown]
# ### Data Cleaning - fix ambiguous columns

# %%
# Remove column 'year' (column 'released' contains a more precise data)
df = df.drop('year', axis=1)

# %%
# Extract the year from the string
df['released'] = df['released'].str.extract('(\d{4})')

# %%
# Verify column 'released' has been modified as intended
df.head(1)
# Out:
#           name rating  genre released  score   votes         director  \
# 0  The Shining      R  Drama     1980    8.4  927000  Stanley Kubrick
#
#          writer            star         country    budget     gross  \
# 0  Stephen King  Jack Nicholson  United Kingdom  19000000  46998772
#
#         company  runtime
# 0  Warner Bros.      146

# %% [markdown]
# ### Data Transformation

# %%
# Sort dataset by column 'gross'
df=df.sort_values(by=['gross'], inplace=False, ascending=False)
df
# Out:
#                                             name     rating   genre released  \
# 5445                                      Avatar      PG-13  Action     2009
# 7445                           Avengers: Endgame      PG-13  Action     2019
# 3045                                     Titanic      PG-13   Drama     1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action     2015
# 7244                      Avengers: Infinity War      PG-13  Action     2018
# ...                                          ...        ...     ...      ...
# 5640                                 Tanner Hall          R   Drama     2015
# 2434                  Philadelphia Experiment II      PG-13  Action     1994
# 3681                                Ginger Snaps  Not Rated   Drama     2001
# 272                                     Parasite          R  Horror     1982
# 3203                                  Trojan War      PG-13  Comedy     1997
#
# ...

# %% [markdown]
# ### Look at Outliers

# %%
df.boxplot(column=['gross'])
# Out:
# <Axes: >

# %% [markdown]
# ### Finding Correlation - Budget vs Gross Earnings

# %%
# Visualization using Scatter Plot & Seaborn
sns.regplot(x='gross', y='budget', data=df, line_kws={"color": "blue"})
plt.scatter(x=df['gross'], y=df['budget'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
# Visualization using Heat Map
correlation_matrix = df.corr(method='pearson', numeric_only='True')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.show()

# %% [markdown]
# ### Finding Correlation - Non-Numeric Columns vs Gross Earnings

# %%
# Correlation among Numeric Columns
df.corr(method='pearson', numeric_only='True')
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# Using factorize - assigns a random numeric value for each unique categorical value
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre  released     score     votes  \
# name      1.000000  0.314800  0.186668  0.262849  0.136453  0.608411
# rating    0.314800  1.000000  0.031419  0.087261 -0.075109  0.121122
# genre     0.186668  0.031419  1.000000  0.071750  0.047421  0.177836
# released  0.262849  0.087261  0.071750  1.000000  0.053108  0.287857
# score     0.136453 -0.075109  0.047421  0.053108  1.000000  0.247863
# votes     0.608411  0.121122  0.177836  0.287857  0.247863  1.000000
# director  0.679808  0.230190  0.131437  0.190556  0.176116  0.472671
# writer    0.764057  0.251470  0.129595  0.230543  0.122357  0.522918
# star      0.599410  0.226007  0.143735  0.242124  0.139126  0.429085
# country   0.124405  0.111309 -0.055109 -0.045134 -0.057087  0.013363
# budget    0.526690  0.283770  0.175071  0.183598 -0.005767  0.317842
# gross     0.986431  0.319778  0.185075  0.272536  0.139819  0.620450
# company   0.631721  0.269792  0.080643  0.134709  0.022732  0.346864
# ...

# %%
correlation_matrix=df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()
